# %%
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize": (12, 8)})

# %%
df = pd.read_csv("all_data.csv")
df
# Out:
#      Unnamed: 0          notebook  \
# 0             0      hmwk01.ipynb
# 1             1      hmwk01.ipynb
# 2             2      hmwk01.ipynb
# 3             3      hmwk01.ipynb
# 4             4      hmwk01.ipynb
# ..          ...               ...
# 816         816  Clustering.ipynb
# 817         817  Clustering.ipynb
# 818         818  Clustering.ipynb
# 819         819  Clustering.ipynb
# 820         820  Clustering.ipynb
#
#                                                   link  cell_id  lineno  \
# 0    https://github.com/scuthbert/DataScience/blob/...       19       1
# 1    https://github.com/scuthbert/DataScience/blob/...       19       1
# 2    https://github.com/scuthbert/DataScience/blob/...       21       1
# 3    https://github.com/scuthbert/DataScience/blob/...       21       1
# 4    https://github.com/scuthbert/DataScience/blob/...       21       2
# ..                                                 ...      ...     ...
# 816  https://github.com/roei60/Data-Science-Hotels/...       16       9
# 817  https://github.com/roei60/Data-Science-Hotels/...       16      10
# 818  https://github.com/roei60/Data-Science-Hotels/...       16      11
# 819  https://github.com/roei60/Data-Science-Hotels/...       16      13
# 820  https://github.com/roei60/Data-Science-Hotels/...       16      14
#
#      end_lineno  col_offset  end_col_offset     type type_details output_type  \
# 0             1          12              72    Call1       dropna    internal
# 1             1          12              79    Call1         copy    internal
# 2             1          18             111    Call1        count    internal
# 3             1         114             175    Call1        count    internal
# 4             2          19             112    Call1        count    internal
# ..          ...         ...             ...      ...          ...         ...
# 816           9           0              28  Assign2          NaN    internal
# 817          10           0              30  Assign1          NaN    internal
# 818          11           0              62    Call1  sort_values    internal
# 819          13           0              65  Assign2          NaN    internal
# 820          14           0               6    Expr1          NaN   revealing
#
#     effect_type                                               code
# 0     enforcing  dfTiDirt.dropna(subset=["Survived", "Pclass", ...
# 1      checking  dfTiDirt.dropna(subset=["Survived", "Pclass", ...
# 2      checking  dfTitanic.loc[(dfTiDirt["Survived"] == 1) & (d...
# 3      checking  dfTitanic.loc[dfTitanic["Pclass"] == 1, ["Surv...
# 4      checking  dfTitanic.loc[(dfTiDirt["Survived"] == 1) & (d...
# ..          ...                                                ...
# 816   enforcing                       hotels["cluster"] = clusters
# 817    checking                     hotels = hotels[[0,"cluster"]]
# 818   enforcing  hotels.sort_values(by=["cluster"],ascending=Tr...
# 819   enforcing  hotels["Count"] = hotels.groupby("cluster")[0]...
# 820    checking                                             hotels
#
# [821 rows x 13 columns]

# %%
sns.histplot(df, x="type")
# Out:
# <AxesSubplot: xlabel='type', ylabel='Count'>

# %%
g = sns.histplot(df, x="type_details")
g.tick_params(axis='x', rotation=90)

# %%
df["type_details"].value_counts()
# Out:
# apply              35
# shape              27
# sort_values        24
# drop               21
# loc                20
# mean               19
# count              18
# head               17
# value_counts       15
# max                15
# copy               15
# astype             14
# columns            13
# describe           12
# dropna             12
# reshape            12
# unique              9
# reset_index         9
# fillna              5
# rename              5
# isnull              5
# concat              5
# replace             4
# quantile            4
# index               4
# std                 2
# tail                2
# size                1
# drop_duplicates     1
# Name: type_details, dtype: int64

# %%
sns.histplot(df, x="output_type")
# Out:
# <AxesSubplot: xlabel='output_type', ylabel='Count'>

# %%
sns.histplot(df, x="effect_type")
# Out:
# <AxesSubplot: xlabel='effect_type', ylabel='Count'>

# %%
df.groupby(by=["output_type", "effect_type"]).size()
# Out:
# output_type  effect_type
# internal     checking       350
#              enforcing      380
# revealing    checking        91
# dtype: int64
