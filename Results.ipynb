# %%
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize": (12, 8)})

# %%
df = pd.read_csv("all_data.csv")
df
# Out:
#      Unnamed: 0          notebook  cell_id  lineno  end_lineno  col_offset  \
# 0             0      hmwk01.ipynb       19       1           1          12
# 1             1      hmwk01.ipynb       19       1           1          12
# 2             2      hmwk01.ipynb       21       1           1          18
# 3             3      hmwk01.ipynb       21       1           1         114
# 4             4      hmwk01.ipynb       21       2           2          19
# ..          ...               ...      ...     ...         ...         ...
# 816         816  Clustering.ipynb       16       9           9           0
# 817         817  Clustering.ipynb       16      10          10           0
# 818         818  Clustering.ipynb       16      11          11           0
# 819         819  Clustering.ipynb       16      13          13           0
# 820         820  Clustering.ipynb       16      14          14           0
#
#      end_col_offset     type  \
# 0                79    Call1
# 1                72    Call1
# 2               111    Call1
# 3               175    Call1
# 4               112    Call1
# ..              ...      ...
# 816              28  Assign2
# 817              30  Assign1
# 818              62    Call1
# 819              65  Assign2
# 820               6    Expr1
#
#                                                   code
# 0    dfTiDirt.dropna(subset=["Survived", "Pclass", ...
# 1    dfTiDirt.dropna(subset=["Survived", "Pclass", ...
# 2    dfTitanic.loc[(dfTiDirt["Survived"] == 1) & (d...
# 3    dfTitanic.loc[dfTitanic["Pclass"] == 1, ["Surv...
# 4    dfTitanic.loc[(dfTiDirt["Survived"] == 1) & (d...
# ..                                                 ...
# 816                       hotels["cluster"] = clusters
# 817                     hotels = hotels[[0,"cluster"]]
# 818  hotels.sort_values(by=["cluster"],ascending=Tr...
# 819  hotels["Count"] = hotels.groupby("cluster")[0]...
# 820                                             hotels
#
# [821 rows x 9 columns]

# %%
sns.histplot(df, x="type")
# Out:
# <AxesSubplot: xlabel='type', ylabel='Count'>
