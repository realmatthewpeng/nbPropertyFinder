# %%
import pandas as pd
import seaborn as sns

sns.set(rc={"figure.figsize": (12, 8)})

# %%
df = pd.read_csv("complete_notebook_analysis/all_data.csv")
df
# Out:
#      Unnamed: 0          notebook  \
# 0             0      hmwk01.ipynb
# 1             1      hmwk01.ipynb
# 2             2      hmwk01.ipynb
# 3             3      hmwk01.ipynb
# 4             4      hmwk01.ipynb
# ..          ...               ...
# 825         825  Clustering.ipynb
# 826         826  Clustering.ipynb
# 827         827  Clustering.ipynb
# 828         828  Clustering.ipynb
# 829         829  Clustering.ipynb
#
#                                                   link  cell_id  lineno  \
# 0    https://github.com/scuthbert/DataScience/blob/...       19       1
# 1    https://github.com/scuthbert/DataScience/blob/...       19       1
# 2    https://github.com/scuthbert/DataScience/blob/...       21       1
# 3    https://github.com/scuthbert/DataScience/blob/...       21       1
# 4    https://github.com/scuthbert/DataScience/blob/...       21       2
# ..                                                 ...      ...     ...
# 825  https://github.com/roei60/Data-Science-Hotels/...       16       9
# 826  https://github.com/roei60/Data-Science-Hotels/...       16      10
# 827  https://github.com/roei60/Data-Science-Hotels/...       16      11
# 828  https://github.com/roei60/Data-Science-Hotels/...       16      13
# 829  https://github.com/roei60/Data-Science-Hotels/...       16      14
#
#      end_lineno  col_offset  end_col_offset     type type_details  \
# 0             1          12              79    Call1         copy
# 1             1          12              72    Call1       dropna
# 2             1          18             111    Call1        count
# 3             1         114             175    Call1        count
# 4             2          19             112    Call1        count
# ..          ...         ...             ...      ...          ...
# 825           9           0              28  Assign2          NaN
# 826          10           0              30  Assign1          NaN
# 827          11           0              62    Call1  sort_values
# 828          13           0              65  Assign2          NaN
# 829          14           0               6    Expr1          NaN
#
#        effect_type                                               code
# 0    uncategorized  dfTiDirt.dropna(subset=["Survived", "Pclass", ...
# 1        enforcing  dfTiDirt.dropna(subset=["Survived", "Pclass", ...
# 2        revealing  dfTitanic.loc[(dfTiDirt["Survived"] == 1) & (d...
# 3        revealing  dfTitanic.loc[dfTitanic["Pclass"] == 1, ["Surv...
# 4        revealing  dfTitanic.loc[(dfTiDirt["Survived"] == 1) & (d...
# ..             ...                                                ...
# 825      enforcing                       hotels["cluster"] = clusters
# 826      reduction                     hotels = hotels[[0,"cluster"]]
# 827      enforcing  hotels.sort_values(by=["cluster"],ascending=Tr...
# 828      enforcing  hotels["Count"] = hotels.groupby("cluster")[0]...
# 829       sampling                                             hotels
#
# [830 rows x 12 columns]

# %%
sns.histplot(df, x="type")
# Out:
# <AxesSubplot: xlabel='type', ylabel='Count'>

# %%
g = sns.histplot(df, x="type_details")
g.tick_params(axis='x', rotation=90)

# %%
sns.histplot(df, x="effect_type")
# Out:
# <AxesSubplot: xlabel='effect_type', ylabel='Count'>

# %%
df2 = pd.read_csv("last_line_analysis/all_last_lines.csv")
df2
# Out:
#      Unnamed: 0         category  \
# 0             0         NO_PRINT
# 1             1         NO_PRINT
# 2             2            PRINT
# 3             3            PRINT
# 4             4        REDUCTION
# ..          ...              ...
# 266         266         NO_PRINT
# 267         267         NO_PRINT
# 268         268  IMPLICIT SAMPLE
# 269         269         NO_PRINT
# 270         270  IMPLICIT SAMPLE
#
#                                                 source
# 0           dfTiDirt = pd.read_csv('titanic_data.csv')
# 1    dfTitanic = dfTiDirt.dropna(subset=["Survived"...
# 2    print("First Class Fraction: {0:.4f}\nSecond C...
# 3    print("First Class Male Fraction: {0:.4f} \t F...
# 4                   print(dfTitanic["Age"].describe())
# ..                                                 ...
# 266       most_checkins = most_checkins.append(new_df)
# 267  checkin_hotel_discount = most_checkins[["Hotel...
# 268                                   normal_dataFrame
# 269           vector = pd.DataFrame.from_records(rows)
# 270                                             hotels
#
# [271 rows x 3 columns]

# %%
sns.histplot(df2, x="category")
# Out:
# <AxesSubplot: xlabel='category', ylabel='Count'>
